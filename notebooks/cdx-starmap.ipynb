# %% [markdown]
# <a href="https://colab.research.google.com/github/pachterlab/JBMMCKP_2023/blob/main/notebooks/cdx-starmap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Install necessary packages if runnning on colab.

# %%
#!pip install scipy
#!pip install anndata
#!pip install scanpy
#!pip install concordex

# %%
import sys, os
import pandas as pd 

import anndata
import scanpy as sc 
from concordex.tools import calculate_concordex

from scipy.cluster.vq import kmeans2

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Data in this example is availabile at the following link: [https://caltech.box.com/v/concordex-data](https://caltech.box.com/v/concordex-data)
#
# Assumes the following file structure:
# <pre>
# |-- parent
# |   |-- notebooks
# |   |   |-- cdx-libd.ipynb
# |   |-- data
# |   |   |-- starmap
# |   |   |   |-- starmap_processed.h5ad
# |   |   |-- ....
#
# </pre>

# %%
result_name = "starmap"

data_dir = "../data"
full_data_dir = os.path.join(data_dir,result_name)

# %% [markdown]
# Load Data

# %%
adata = sc.read_h5ad(os.path.join(full_data_dir, 'starmap_processed.h5ad'))

# %%
adata.var_names_make_unique()
adata.layers["counts"] = adata.X.copy()

# %%
# Setup concordex params
n_shrs = 7
label = "X_pca"
use_rep = "spatial"
n_neighbors = 30 # the default

calculate_concordex(
        adata, label, 
        use_rep=use_rep, 
        n_neighbors=n_neighbors
)

use_louvain=False
if use_louvain: 
    sc.pp.neighbors(adata, use_rep="X_nbc")
    sc.tl.louvain(adata, resolution=louvain_resolution)
    
else:
    _, shr = kmeans2(adata.obsm['X_nbc'], n_shrs, seed=9)
    adata.obs['shr'] = pd.Categorical(shr)
# Out:
# Computing nearest neighbors...
#
# Computing neighborhood consolidation matrix...

# %%
sc.pl.spatial(adata, color='shr',spot_size=10, size=10)
